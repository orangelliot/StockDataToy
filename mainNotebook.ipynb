# %%
import os
os.environ['PYARROW_IGNORE_TIMEZONE']='1'
os.environ['PYSPARK_DRIVER_PYTHON']='C:/Users/ellio/miniconda3/envs/bigdata/python.exe'
os.environ['PYSPARK_PYTHON']='C:/Users/ellio/miniconda3/envs/bigdata/python.exe'

import requests
import pyspark.pandas as ps
import pandas as pd
from pyspark.sql import SparkSession
from dotenv import load_dotenv

load_dotenv()

AV_KEY = os.getenv('AV_KEY')
FUNCTION = 'TIME_SERIES_INTRADAY'
SYMBOL = 'IBM'
INTERVAL = '5min'

spark = SparkSession\
        .builder\
        .master('local')\
        .appName('StockDataToy')\
        .getOrCreate()

nasdaq_screener = pd.read_csv('nasdaq_screener.csv')

print(nasdaq_screener.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7234 entries, 0 to 7233
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      7233 non-null   object
#  1   Name        7234 non-null   object
#  2   Last Sale   7234 non-null   object
#  3   Net Change  7234 non-null   float64
#  4   % Change    7234 non-null   object
#  5   Market Cap  6815 non-null   float64
#  6   Country     6932 non-null   object
#  7   IPO Year    4122 non-null   float64
#  8   Volume      7234 non-null   int64
#  9   Sector      6453 non-null   object
#  10  Industry    6453 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 621.8+ KB
# None

# %%
import yfinance as yf
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

schema = StructType([
    StructField("Symbol", StringType(), True)#,
    #StructField("")
])

inds = nasdaq_screener.Industry.unique()
stocks_df = ps.DataFrame([])

for ind in inds:
    ind_data[ind] = ps.
    ind_companies = nasdaq_screener[nasdaq_screener['Industry'] == ind]['Symbol'].values.tolist()
    ind_companies = [item for item in ind_companies if isinstance(item, str)]
    tickers = yf.Tickers(" ".join(ind_companies),)
# Out:
# Biotechnology: Laboratory Analytical Instruments yfinance.Tickers object <A,AVTR,AXDX,BIO,BNGO,BRKR,EYPT,HBIO,LAB,MTD,NAUT,OLK,PACB,PRE,PRENW,PRPO,QTRX,RVTY,TXG,WAT>
# =========================================================================
# Aluminum yfinance.Tickers object <AA,CENX>
# =========================================================================
# Other Consumer Services yfinance.Tickers object <AACG,AFYA,AIU,AMBO,APEI,ARL,ASPS,ATGE,BEDU,BFAM,BLW,BOXL,BTCT,BTCTW,CHGG,CLEU,COE,CRAI,CSV,DAO,DFIN,DLPN,EDTK,EDU,EEIQ,EJH,EM,EVH,EVI,FEDU,GHC,GNS,GOTU,GSUN,HRB,IH,IT,JWEL,JZ,KUKE,LAUR,LINC,LOPE,LRN,LXEH,MAPS,MAPSW,MRM,MYND,NVEE,OCG,OXSQG,PFMT,PINC,PRDO,QSG,RCM,RGS,SCI,SE,STG,STRA,TAL,TCTM,TISI,TPVG,UDMY,UNF,UTI,VERB,VERBW,VSTA,VTRU,WAFU,WW,XWEL,YELP,YQ,ZCMD>
# =========================================================================
# Blank Checks yfinance.Tickers object <AACI,AACIW,AACT,ACAB,ACABU,ACAC,ACACW,ADRT,AEAE,AFAR,AIB,AIBBR,AIMAU,AIMBU,AISP,AISPW,ALCC,ALCY,ALCYU,ALSA,ALSAR,ALSAU,ALSAW,ALTU,ALTUU,ALTUW,APAC,APACU,APACW,APCA,APLM,APLMW,APXI,AQU,AQUNR,ARRW,ARRWU,ARRWW,ASCA,ASCAR,ASCAU,ASCAW,ASCB,ASCBR,ATEK,ATMC,ATMCR,ATMCU,ATMCW,ATMV,ATMVU,AVHI,AVHIU,AVHIW,BACA,BAER,BAERW,BCSA,BCSAU,BEEP,BENF,BENFW,BFAC,BHAC,BHACU,BHACW,BITE,BLAC,BLACR,BLACW,BLEU,BLEUR,BLUA,BNIXR,BNIXW,BNZIW,BOCN,BRAC,BREZ,BREZR,BREZW,BRKH,BRKHW,BRLS,BRLSW,BUJA,BUJAR,BUJAW,BWAQ,BWAQR,BWAQW,BYNO,BYNOW,CAPT,CAPTW,CBRG,CBRGU,CCTS,CDAQ,CDAQU,CDAQW,CETU,CFFS,CFFSW,CHAA,CITE,CITEW,CLOE,CLRC,CLRCR,CMCA,CMCAU,CMCAW,CNDA,CNDB,CNGL,CNGLU,CNGLW,COCH,COCHW,CONX,CONXU,CONXW,COOL,COOLW,CRGO,CRGOW,CSLM,CSLMW,CVII,CVIIU,CVIIW,DECA,DECAW,DHAIW,DHCA,DHCAU,DHCAW,DIST,DISTR,DISTW,DMYY,DPCS,DSAQ,DUET,EAC,EACPW,EMCG,EMLD,EMLDW,ESAC,ESACU,ESACW,ESHA,ETAO,EUDA,EVE,EVGR,FEXD,FIAC,FIACW,FLFV,FLFVW,FLYX,FNVT,FORL,FORLU,FTII,FTIIW,GAMC,GAMCW,GAQ,GATE,GBBK,GBBKW,GDST,GDSTR,GHIX,GHIXW,GMFI,GMFIU,GMFIW,GODN,GPAC,GPACW,GRNT,GTAC,HAIA,HCMA,HCMAU,HCMAW,HCVI,HCVIU,HCVIW,HHGC,HOVR,HOVRW,HSPO,HSPOR,HSPOU,HSPOW,HUDA,IGTA,IGTAR,IGTAU,IGTAW,INAQ,INAQW,INTE,INTEW,IPXX,IPXXU,IPXXW,IRAA,IRRX,ISPO,ISPOW,ISRL,ISRLW,IVCA,IVCB,IVCBW,IVCP,IVCPU,IVCPW,IXAQ,JTAI,JTAIW,JWSM,KACL,KACLR,KCGI,KRNL,KRNLU,KRNLW,KYCH,KYCHR,LANV,LATG,LBBB,LBBBR,LBBBU,LBBBW,LCW,LIBY,LIBYU,LIBYW,LOTWW,LVRO,LVROW,MACA,MACAW,MAQC,MAQCW,MARX,MARXR,MBTC,MBTCR,MCAA,MCAAW,MCAC,MCACR,MCACW,MCAF,MCAFU,MCAG,MITA,MLEC,MLECW,MMV,MMVWW,MNTN,MOBXW,MRDB,MSAIW,MSSA,MSSAW,MTAL,NBST,NBSTW,NOVV,NOVVR,NOVVW,NPAB,NUKK,NUKKW,NVNIW,OAKU,OAKUR,OCAX,ONYX,OPTX,OPTXW,OSI,OXSQ,OXSQZ,PEGR,PEGRU,PEPL,PFTA,PFTAU,PFTAW,PGSS,PHYT,PLAO,PLMI,PLMIW,PLTN,PLTNR,PLTNW,PMGM,PMGMW,PNST,PORT,PPHP,PPHPR,PPHPW,PPYA,PPYAW,PRLH,PTWO,PTWOU,PUCK,PUCKW,PWUP,PWUPU,QDRO,QDROU,QOMO,QOMOW,RCFA,RDZN,RDZNW,RENE,RFAC,RMGC,RMGCU,RMGCW,ROCL,ROCLU,ROCLW,ROSS,RRAC,RWOD,RWODR,SBXC,SCRM,SCRMU,SCRMW,SDA,SDAWW,SEDA,SEPA,SEPAW,SKGR,SKGRW,SLAM,SLAMU,SLAMW,SLNA,SLNAW,SMXWW,SOAR,STI,SVII,SVIIU,SWSS,SWSSU,SWSSW,TBMC,TBMCR,TCOA,TENK,TENKR,TETE,TETEU,TETEW,TGAA,TGAAW,THCH,TLGY,TMTC,TMTCR,TMTCU,TRIS,TRON,TRONW,TRTL,TTSH,TWLV,TWLVW,USCT,USCTW,VCXB,VFS,VMCA,VSAC,WEL,WINV,WNNR,XFIN,XFINW,XPDB,XPDBU,XPDBW,YS,YSBPW,ZAPPW,ZCAR,ZCARW,ZLS,ZLSWU>
# =========================================================================
# Biotechnology: Pharmaceutical Preparations yfinance.Tickers object <AADI,ABBV,ABCL,ABEO,ABOS,ABSI,ABT,ABVC,ACAD,ACET,ACIU,ACLX,ACRS,ACXP,ADAG,ADCT,ADIL,ADTX,ADXN,AEON,AEZS,AFMD,AGE,AGIO,AGRX,AIMD,AIMDW,AKBA,AKRO,AKTX,ALDX,ALGS,ALIM,ALKS,ALLK,ALLR,ALNY,ALPN,ALRN,ALT,ALXO,AMGN,AMLX,AMPE,AMPH,AMRN,AMRX,ANAB,ANEB,ANIP,ANIX,ANNX,ANTX,ANVS,APLS,APLT,APM,APRE,APVO,AQST,ARCT,ARDX,ARQT,ARTL,ARTLW,ARVN,ARWR,ASLN,ASMB,ASND,ASRT,ATAI,ATHE,ATNF,ATNFW,ATNM,ATOS,ATXI,ATXS,AUPH,AURA,AVDL,AVTE,AVTX,AXSM,AYTU,AZN,AZTR,BBIO,BCDAW,BCEL,BCTXW,BCYC,BDRX,BFRI,BFRIW,BGNE,BGXX,BHC,BHVN,BIOR,BIVI,BLRX,BLTE,BMEA,BMRN,BMY,BNTC,BOLT,BPMC,BPTH,BPTS,BRNS,BTAI,BTTX,BYSI,CABA,CADL,CALC,CALT,CANF,CAPR,CARA,CARM,CASI,CBAY,CCCC,CDMO,CDT,CDTTW,CELU,CELUW,CELZ,CERE,CGEM,CGTX,CING,CINGW,CKPT,CLLS,CLNN,CLNNW,CLRB,CLSD,CMMB,CMND,CMPS,CMPX,CMRX,CNSP,CNTA,CNTB,CNTX,COCP,COGT,COLL,CORT,COYA,CPHI,CPIX,CPRX,CRBP,CRMD,CRNX,CRVO,CRVS,CTLT,CTMX,CTXR,CUE,CVAC,CYCC,CYCCP,CYCN,CYRX,CYT,CYTK,CYTO,DARE,DAWN,DCPH,DERM,DMAC,DNTH,DOMH,DRMA,DRRX,DRTS,DSGN,DVAX,EBS,EDIT,EDSA,EFTR,EFTRW,EGRX,ELAN,ELDN,ELEV,ELTX,ELVN,ELYM,ENLV,ENSC,ENVB,EOLS,EQ,ERAS,ERNA,ESPR,ETNB,ETON,EVO,EVOK,EWTX,EYEN,FBIO,FBIOP,FBRX,FDMT,FGEN,FIXX,FNCH,FOLD,FULC,FWBI,GALT,GANX,GBIO,GDTC,GERN,GHRS,GHSI,GLMD,GLPG,GLSI,GLTO,GLUE,GLYC,GMAB,GNLX,GNPX,GOSS,GOVX,GRFS,GRI,GRTX,GSK,GTBP,GTHX,GYRE,HARP,HCM,HCWB,HEPA,HLVX,HOOK,HOTH,HOWL,HRMY,HROW,HROWL,HROWM,HRTX,HUMA,HUMAW,IBIO,ICU,ICUCW,IDYA,IFRX,IGC,IGMS,IKNA,IKT,IMAB,IMMP,IMNN,IMRN,IMRX,IMUX,INAB,INBX,INCR,INDP,INDV,INM,INSM,INTS,INVA,INZY,IOBT,IONS,IPA,IRON,IRWD,ITCI,ITRM,IVA,IVVD,JAGX,JANX,JAZZ,JNJ,JSPR,JSPRW,KA,KALA,KALV,KMDA,KNSA,KNTE,KROS,KRRO,KRTX,KTRA,KTTA,KTTAW,KZIA,KZR,LBPH,LEGN,LEXX,LEXXW,LFCR,LFVN,LGND,LIAN,LIPO,LIXT,LIXTW,LLY,LPCN,LPTX,LQDA,LRMR,LTRN,LUMO,LVTX,LXRX,LYEL,MACK,MAIA,MBIO,MBRX,MCRB,MDGL,MDXG,MEIP,MGNX,MIRA,MIRM,MIST,MLTX,MLYS,MNKD,MNOV,MNPR,MOR,MORF,MREO,MRK,MRKR,MRNS,MRSN,MRUS,MRVI,MTEM,MTNB,MYNZ,NAMS,NAMSW,NATR,NBSE,NBTX,NCNA,NERV,NEXI,NGM,NGNE,NKTR,NKTX,NLSP,NLSPW,NNVC,NRBO,NRIX,NRSN,NRSNW,NRXP,NRXPW,NTBL,NTRB,NUVB,NUVL,NVS,NXTC,OABI,OABIW,OCEA,OCEAW,OCGN,OCS,OCSAW,OCUL,OCUP,OGEN,OGI,OGN,OLMA,OMER,OMGA,ONCO,ONCT,ONCY,ONTX,OPK,OPTN,ORGO,ORGS,ORIC,ORMP,OTLK,OVID,PAHC,PALI,PASG,PBH,PBYI,PCRX,PCSA,PCVX,PDSB,PEPG,PFE,PGEN,PHAR,PHAT,PHIO,PHVS,PIRS,PLRX,PMN,PPBT,PRAX,PRFX,PRGO,PROC,PROCW,PRPH,PRQR,PRTA,PRTC,PTCT,PTGX,PTIX,PTIXW,PTN,PTPI,PULM,PYXS,QLGN,QLI,QSI,QSIAW,QURE,RAPT,RARE,RCKT,RCKTW,RCUS,RDHL,RDY,REGN,RENB,REPL,REVB,REVBW,RFL,RGLS,RIGL,RLMD,RLYB,RMTI,RNA,RNAC,RNAZ,RNXT,ROIV,RPHM,RPRX,RPTX,RVNC,RVPH,RVPHW,RXRX,RYTM,RZLT,SABS,SAGE,SAVA,SBFM,SBFMW,SCLX,SCLXW,SCPH,SCPX,SCTL,SCYX,SDGR,SEEL,SHOT,SHOTW,SHPH,SIGA,SLGL,SLN,SLNO,SLRN,SLRX,SLS,SMMT,SNDX,SNGX,SNOA,SNSE,SNTI,SNY,SONN,SPRC,SPRO,SPRY,SRPT,STOK,STTK,SUPN,SVRA,SXTC,SXTP,SXTPW,SYBX,SYRE,SYRS,TAK,TARO,TBPH,TCRT,TCRX,TENX,TERN,TEVA,TFFP,TGTX,THAR,THRD,TIL,TLPH,TLSA,TNGX,TNXP,TOVX,TPST,TRDA,TRML,TRVI,TRVN,TSHA,TSVT,TVTX,TXMD,TYRA,UBX,UNCY,UPC,URGN,UTHR,VAXX,VBIV,VCNX,VERA,VERU,VIGL,VINC,VIR,VIRI,VIRX,VKTX,VNDA,VOR,VRCA,VRDN,VRNA,VSTM,VTGN,VTVT,VYGR,VYNE,WVE,XBIO,XBIOW,XBIT,XCUR,XENE,XERS,XLO,XNCR,XOMA,XOMAO,XOMAP,XRTX,XTLB,YCBD,YMAB,ZLAB,ZNTL,ZOM,ZTS,ZVRA,ZVSA,ZYME>
# =========================================================================
# Finance: Consumer Services yfinance.Tickers object <AAGR,AAGRW,AIHS,AMTD,APCX,APCXW,ARBK,ARCC,ATLC,ATLCL,ATLCP,ATLCZ,AXP,BCOW,BETR,BETRW,BITF,BKCC,BTBT,BTCS,BTM,BTMWW,BTOG,BUR,CACC,CAUD,CCAP,CGBD,CLSK,CMPO,CMPOW,CNF,COIN,COOP,CPSS,CURO,DFS,DNB,DXF,EFX,ENVA,FCRX,FINV,FRLA,GAIN,GAINL,GAINN,GAINZ,GBDC,GDOT,GECC,GECCM,GEGGL,GFAI,GFAIW,GHI,GHLD,GSBD,HIVE,HKD,HRZN,HTFB,IROQ,JBK,JFIN,JFU,JNVR,JSM,KTN,LC,LDI,LMFA,LPRO,LRFC,LU,LX,MCO,MEGL,MFH,MFIN,MGLD,MIGI,NFJ,NNI,NU,NXTP,OCN,OCSL,OMF,OPFI,OPRT,PAPL,PFLT,PFSI,PFX,PFXNZ,PGY,PGYWW,PNNT,PRAA,PROP,PTMN,PWP,PYT,QD,QFIN,RAND,RKT,RM,SHFS,SHFSW,SLM,SLMBP,SNFCA,SNTG,SOS,SPGI,SSSS,SSSSL,SYF,TRU,UPST,UWMC,VEL,WD,WRLD,XYF,YRD>
# =========================================================================
# Air Freight/Delivery Services yfinance.Tickers object <AAL,AIRT,AIRTP,ALGT,ALK,ATSG,AZUL,CPA,DAL,FDX,HA,JBLU,JEQ,LUV,MESA,RYAAY,SAVE,SKYW,SNCY,UAL,ULCC,VLRS>
# =========================================================================
# Real Estate yfinance.Tickers object <AAMC,AHH,BEKE,BOC,BPYPM,BPYPN,BPYPO,CBRE,CHCI,COLD,CRESW,CRESY,CWD,CWK,DOMA,DUO,EFC,EXPI,FLJ,FOR,FPH,FRPH,FTHM,GGE,GOOD,GOODN,GOODO,HOUS,HPP,INVH,JLL,KW,LEJU,LUXH,MDJH,MLP,MMI,NMRK,NYC,OMH,OPAD,OPEN,OPINL,RDFN,RHE,RMAX,RMR,SRG,STHO,SYT,TCI,TCN,TRC,TRNO,UE,VAC,VINO,WETH>
# =========================================================================
# Life Insurance yfinance.Tickers object <AAME,AEG,AEL,AIG,BHF,BHFAL,BHFAM,BHFAN,BHFAO,BHFAP,CIA,CNO,CRBG,FG,GL,GNW,JXN,LNC,MET,NWLI,PFH,PRH,PRI,PRS,PRU,PUK,RGA,RZB,RZC,SLF,VERY,VOYA>
# =========================================================================
# Diversified Commercial Services yfinance.Tickers object <AAN,ABM,ADT,AER,AL,ALLE,BBWI,CASY,CHPT,CTOS,FCFS,FORR,FPAY,FTDR,HSII,IPX,IVP,JOB,KFY,KPLT,KPLTW,KPTI,LESL,MGRC,MPU,NHTC,NVRI,PAYX,PIXY,PRG,ROL,SECO,SST,TGH,TOMZ,UPBD,VCIG,VVX,YHGJ,ZIP>
# =========================================================================
# Semiconductors yfinance.Tickers object <AAOI,ADI,AIP,ALGM,AMAT,AMBA,AMD,AMKR,AOSL,ARRY,ASTI,ASX,ASYS,ATOM,AVGO,AXTI,BEEM,BEEMW,CAN,CRDO,CRUS,CSIQ,CSLR,DIOD,DQ,EBON,EMKR,ENPH,ENTG,FORM,FSLR,FTCI,GFS,GSIT,HIMX,ICG,ICHR,IMOS,INDI,INTC,IPGP,IPWR,ISUN,JKS,KLIC,KOPN,LAES,LASR,LEDS,LPTH,LSCC,MAXN,MCHP,MMAT,MPWR,MRAM,MRVL,MTSI,MU,MX,MXL,NVDA,NVEC,NVTS,NXPI,NXT,ON,OSIS,PLAB,POET,POWI,PRSO,PXLW,QRVO,QUIK,RMBS,SEDG,SGH,SHLS,SIMO,SING,SITM,SKYT,SLAB,SMTC,SOL,SPCB,SPI,SPWR,SQNS,STM,SWKS,SYNA,TGAN,TSEM,TSM,TXN,TYGO,UCTT,UMC,VECO,VIAO,VIAV,VLN,WISA,WOLF,XPER>
# =========================================================================
# Industrial Machinery/Components yfinance.Tickers object <AAON,ACLS,ACMR,ACU,ADN,ADNWW,AEIS,AGCO,ALG,ALTG,AME,AMPX,ARTW,ASML,ATKR,AULT,AWIN,AWINW,AZTA,BC,BE,BLDP,BMI,BODI,BURU,BYRN,CARR,CBAT,CGNX,CHX,CIX,CLIR,CMI,CODA,CPTN,CPTNW,CRKN,CTS,CVR,CVV,CW,CYD,DAIO,DASH,DE,DHR,DOV,DXPE,EAF,EFXT,EKSO,ELBM,ELSE,EML,ENCP,ENCPU,ENCPW,ENR,ENS,ENVX,EOSE,EOSEW,EPAC,ERII,ESP,ETN,FARO,FCEL,FCUV,FLNC,FLUX,FREY,FTV,GEOS,GETY,GHM,GIC,GLW,GPRO,GRMN,GTEC,GTES,GWH,HIHO,HLMN,HLP,HOLI,HURC,HYFM,IR,ITW,IVAC,JBT,JCI,KAI,KE,KEYS,KITT,KITTW,KMT,KNW,KRNT,LASE,LCUT,LECO,LGL,LHX,LII,LINK,LIQT,LNN,LPL,LRCX,LUNR,LUNRW,MAX,MIDD,MIND,MINDP,MIR,MKSI,MLAB,MNTX,MRC,MSM,MVIS,MVST,MVSTW,NDSN,NEON,NEOV,NEOVW,NN,NNAVW,NNBR,NOC,NOVT,NPWR,NRGV,NSYS,NVOS,NVT,NVX,OC,ONTO,OPTT,OST,OUST,PI,PLUG,PNR,POLA,RETO,ROG,ROK,ROP,RUN,SCX,SEAT,SEATW,SENS,SGE,SILV,SMX,SNA,SOTK,SPB,SPEC,SPECW,SPXC,SSD,ST,SVT,SWK,SXI,SYM,SYPR,TAYD,TBLT,TDY,TEL,THR,THRY,TMO,TNC,TPIC,TRMB,TRT,TWIN,ULBI,VICR,VJET,VNT,VREX,VRT,VUZI,WSO,WTMA,WTMAR,WWD,XMTR,ZWS>
# =========================================================================
# Auto & Home Supply Stores yfinance.Tickers object <AAP,AZO,HZO,ONEW,ORLY,PRTS>
# =========================================================================
# Computer Manufacturing yfinance.Tickers object <AAPL,CRSR,DELL,HPQ,IBM,NICE,OMCL,OSS,QUBT,SCKT,SILC,SMCI,ZEPP>
# =========================================================================
# Real Estate Investment Trusts yfinance.Tickers object <AAT,ABR,ACR,ACRE,ADC,AFCG,AGNC,AGNCL,AGNCM,AGNCN,AGNCO,AGNCP,AHR,AHT,AIRC,AIV,AJX,AJXA,AKR,ALEX,ALX,AMH,AMT,AOMR,APLE,ARE,ARI,ARR,AVB,BDN,BFS,BHM,BHR,BNL,BRSP,BRT,BRX,BXMT,BXP,CBL,CCI,CDP,CHCT,CHMI,CIM,CIO,CLDT,CLPR,CMCT,CMTG,CPT,CSR,CTO,CTRE,CUBE,CUZ,CXW,DBRG,DEA,DEI,DHC,DHCNI,DHCNL,DLR,DOC,DRH,DX,EARN,EGP,ELME,ELS,EPR,EPRT,EQC,EQIX,EQR,ESRT,ESS,EXR,FBRT,FCPT,FPI,FR,FRT,FSP,GIPR,GIPRW,GLPI,GMRE,GNL,GPMT,GTY,HASI,HHH,HIW,HR,HST,HTIA,HTIBP,IIPR,ILPT,INN,IOR,IRM,IRT,IVR,IVT,JBGS,KIM,KRC,KREF,KRG,LADR,LAMR,LAND,LANDM,LANDO,LANDP,LFT,LOAN,LTC,LXP,MAA,MAC,MDRR,MDRRP,MFA,MITT,MOB,MPW,NHI,NLY,NNN,NREF,NSA,NTST,NXRT,NYMT,NYMTL,NYMTM,NYMTN,NYMTZ,O,OHI,OLP,ONL,OPI,ORC,OUT,PCH,PEB,PECO,PGRE,PINE,PK,PKST,PLD,PLYM,PMT,PSA,PSTL,PW,RC,RCB,RCC,REFI,REG,REXR,RHP,RITM,RLJ,ROIC,RWT,RYN,SACC,SACH,SAFE,SBAC,SBRA,SCCB,SCCC,SCCD,SCCE,SCCF,SCCG,SELF,SEVN,SHO,SITC,SKT,SLG,SOHO,SOHOB,SOHON,SOHOO,SPG,SQFT,SQFTP,SQFTW,STAG,STRW,STWD,SUI,SVC,TPTA,TRTX,TWO,TWOA,UDR,UHT,UMH,UNIT,VICI,VNO,VRE,VTR,WELL,WHLR,WHLRD,WHLRL,WHLRP,WPC,WSR,WY>
# =========================================================================
# nan yfinance.Tickers object <>
# =========================================================================
# Investment Managers yfinance.Tickers object <AB,ABL,ABLLW,ACP,ADX,AFT,AGBA,AGBAW,ALTI,AMG,AMK,AMP,AOD,APAM,APO,ARDC,ARES,ASG,ASGI,BEN,BGH,BRDG,BSIG,BTO,BTT,BX,BXMX,BYM,CAF,CEV,CG,CGABL,CGO,CHI,CHN,CHW,CHY,CMU,CNS,CTR,CUBA,CXE,CXH,DFP,DHIL,DLY,DNP,DSM,DTF,EDF,EHI,EMO,EOD,ETG,ETO,ETW,EVF,EVG,EVR,FAX,FCO,FFA,FHI,FMN,FOF,FSD,FSK,FTHY,FUND,GAB,GAM,GBAB,GDL,GDV,GF,GGZ,GROW,HCXY,HEQ,HLI,HLNE,HNNA,HNNAZ,HPS,HQL,HTGC,HYB,HYI,HYW,IGA,IGI,IHD,IIM,INSI,IVZ,JGH,JHG,JLS,JPC,KF,KIO,KKR,KTH,LAZ,MEGI,MGR,MGRB,MGRD,MHI,MIO,MMD,MMU,MORN,MRCC,NAC,NAD,NAN,NCA,NCPL,NCPLW,NIE,NMAI,NNY,NOAH,NOM,NPCT,NPV,NUW,NVG,NXC,NXDT,OBDC,OWL,OXLC,OXLCM,OXLCN,OXLCO,OXLCP,PAX,PAXS,PCN,PCQ,PFD,PGZ,PHD,PHT,PJT,PML,PMM,PSF,PTY,PUYI,PX,PYN,PZC,RA,RCG,RCS,RFI,RILY,RILYG,RILYK,RILYL,RILYM,RILYN,RILYO,RILYP,RILYT,RILYZ,RLTY,RMMZ,RMT,RNP,RSF,SAJ,SAMG,SAR,SAT,SAY,SAZ,SOR,STEW,STK,TBLD,TPG,TPZ,TSI,TSLX,TYG,UTG,VALU,VCTR,VGI,VINP,VRTS,WHG,XFLT,ZTR>
# =========================================================================
# Metal Mining yfinance.Tickers object <ABAT,AMLI,BHP,CLF,DDC,ERO,FCX,HBM,IE,LAC,LZM,MP,MSB,NB,NEXA,NGD,NIOBW,PZG,RIO,SCCO,SGML,SOJE,THM,TMC,USAS,USAU,VALE>
# =========================================================================
# Major Banks yfinance.Tickers object <ABCB,ACNB,AFBI,ALLY,ALRS,AMNB,AMTB,AROW,ASB,ASBA,ASRV,ATLO,AUB,AUBN,BAC,BANC,BANF,BANFP,BANR,BBD,BBDO,BCAL,BCML,BFC,BFST,BHB,BHRB,BK,BMRC,BMTX,BOH,BOKF,BOTJ,BPOP,BPOPM,BPRN,BSRR,BSVN,BUSE,BWB,BWBBP,BWFG,BY,C,CAC,CADE,CALB,CARE,CASH,CATC,CATY,CBAN,CBFV,CBNK,CBSH,CBU,CCB,CCBG,CCNE,CCNEP,CFB,CFBK,CFFI,CFG,CFR,CFSB,CHCO,CHMG,CIVB,CMA,CNOB,CNOBP,COF,COFS,COLB,CPF,CSTR,CTBI,CUBB,CUBI,CVBF,CVCY,CWBC,CZFS,CZNC,DB,DCOM,DCOMP,EBMT,EBTC,EFSC,EFSCP,EGBN,EQBK,EVBN,EWBC,FBIZ,FBK,FBMS,FBNC,FBP,FCBC,FCCO,FCF,FCNCA,FCNCO,FCNCP,FDBC,FFBC,FFIC,FFIN,FFWM,FHB,FHN,FIBK,FISI,FITB,FITBI,FITBO,FITBP,FLIC,FMBH,FMNB,FNB,FNCB,FNLC,FRAF,FRBA,FRME,FRMEP,FRST,FULT,FULTP,FUNC,FUSB,FVCB,FXNC,GABC,GBCI,GBNY,GLBZ,GNTY,GSBC,HAFC,HBAN,HBANL,HBANM,HBANP,HBNC,HBT,HIFS,HMST,HOMB,HONE,HOPE,HTBK,HTH,HTLF,HTLFP,HWBK,HWC,HWCPZ,IBCP,IBOC,IBTX,INBK,INBKZ,INDB,ISTR,ITUB,JMSB,JPM,KEY,LARK,LBAI,LCNB,LKFN,LOB,MBCN,MBIN,MBINM,MBINN,MBINO,MBINP,MBWM,MCB,MCBC,MCBS,MFG,MNSB,MNSBP,MOFG,MPB,MRBK,MSBI,MSBIP,MTB,MVBF,MYFW,NBHC,NBN,NBTB,NEWT,NEWTI,NEWTL,NEWTZ,NIC,NKSH,NTRS,NTRSO,NWBI,NWFL,OBK,OBT,OCFC,OCFCP,OFG,OLO,ONB,ONBPO,ONBPP,OPBK,OPHC,OPOF,ORRF,OSBC,OVBC,OVLY,OZK,OZKAP,PB,PBHC,PCB,PEBK,PEBO,PFBC,PFC,PFIS,PKBK,PNBK,PNC,PNFP,PNFPP,PPBI,PRK,PWOD,QCRH,RBB,RBCAA,RBKB,RF,RNST,RVSB,SASR,SBCF,SBFG,SBSI,SFBS,SFNC,SFST,SHBI,SHG,SMBK,SMMF,SNV,SPFI,SRCE,SSB,SSBI,STBA,STEL,STT,SYBT,TBBK,TCBC,TCBI,TCBIO,TCBK,TFC,TFIN,TFINP,THFF,TMP,TOWN,TRMK,TRST,UBCP,UBFO,UBS,UBSI,UCBI,UCBIO,UMBF,UNB,UNTY,USB,USCB,UVSP,VABK,VBFC,VBTX,VLY,VLYPO,VLYPP,WABC,WAFD,WAFDP,WAL,WASH,WBS,WFC,WSBC,WSBCP,WSFS,WTBA,WTFC,WTFCM,WTFCP,ZION,ZIONL,ZIONO,ZIONP>
# =========================================================================
# Beverages (Production/Distribution) yfinance.Tickers object <ABEV,BRCC,BTTR,BUD,CCEP,CCU,CELH,COCO,COKE,DEO,EAST,FIZZ,FMX,KDP,KO,KOF,MGPI,MNST,NAPA,PEP,PRMW,SAM,SBEV,STZ,TAP,VINE,VWE,VWEWW,WEST,WESTW,WVVI,WVVIP,ZVIA>
# =========================================================================
# Retail-Auto Dealers and Gas Stations yfinance.Tickers object <ABG,CSAN,CVNA,CWH,CZOO,GORV,GPI,JZXN,KAR,KMX,KXIN,MTBL,MUSA,PAG,RUSHB,SAH,UCAR>
# =========================================================================
# Biotechnology: In Vitro & In Vivo Diagnostic Substances yfinance.Tickers object <ABIO,ACHV,APDN,BIAF,BIAFW,BMRA,CLDX,ENTA,ICCC,IDXX,KPRX,LNTH,MYGN,MYMD,NEOG,NTLA,OCX,TRIB,VRAX>
# =========================================================================
# Hotels/Resorts yfinance.Tickers object <ABNB,ATAT,BALY,BYD,CHH,CNTY,CZR,FLL,GHG,H,HGV,HLT,HTHT,IHG,LTH,LVS,MAR,MCRI,MGM,MLCO,MSC,OSW,PENN,PLNT,PLYA,RRBI,RRR,SHCO,SOND,SONDW,TH,TNL,WH,WYNN,XHR>
# =========================================================================
# Computer Software: Programming Data Processing yfinance.Tickers object <ABTS,BIDU,BZ,CDLX,CEVA,CNET,DADA,DOYU,DRCT,DWAC,DWACU,DWACW,EB,EVER,FDS,FLUT,GAN,GDS,GIGM,GOOG,GOOGL,GROM,GROMW,HCAT,HOLO,HOLOW,HRYU,HUYA,IAC,IAS,IPDN,JG,KIND,LGCL,META,MGNI,MTCH,NEXN,OB,OBLG,OCFT,ONFO,ONFOW,PINS,PT,SABR,SANG,SIFY,SMWB,SNAP,SOGP,SRAD,TBLA,TBLAW,TRIP,TRUE,TTD,WB,YALA,ZM>
# =========================================================================
# Pharmaceuticals and Biotechnology yfinance.Tickers object <ABUS,ACB,ACST,APTO,BCTX,CGC,CLVR,CLVRW,CRDL,CYBN,DRUG,EPIX,FENC,FLGC,HUGE,IMCC,LSDI,MNMD,SNDL,THTX>
# =========================================================================
# Investment Bankers/Brokers/Service yfinance.Tickers object <AC,AMRK,APLD,BGC,BKT,BLK,CBOE,CIFR,CIFRW,CII,CME,COHN,EEFT,EOT,ETB,ETV,ETX,EVN,FRA,FRHC,FUTU,GJH,GJP,GJS,GJT,GREE,GREEL,GS,HGAS,IBKR,ICE,IHT,JEF,LGHL,LGHLW,LPLA,MC,MHD,MHN,MIY,MKTX,MQT,MQY,MS,MUA,MUC,MUE,MUI,MUJ,MVF,MVT,MYD,MYI,NAVI,NDAQ,NMR,OPY,PIPR,RJF,SCHW,SDIG,SEIC,SF,SFB,SIEB,SNEX,TELL,TIGR,TOP,TROW,TW,UROY,USIO,VIRT,WT,XP>
# =========================================================================
# Metal Fabrications yfinance.Tickers object <ACA,AESI,AMSC,AQMS,B,BKR,BWEN,CR,CSTM,DNOW,DRQ,DTI,FELE,FET,FSTR,FTI,GIFI,GNRC,GTLS,HII,HLIO,HWM,KALU,MATW,MLI,MWA,NISN,NOV,NR,NX,OIS,PH,RAYA,RBC,RBCP,RS,RYI,SDPI,SOI,SYTA,SYTAW,TG,TKR,TPCS,TSAT,UAMY,VATE,VMI,WFRD,WHD,WIRE,WTS,ZEUS,ZKIN>
# =========================================================================
# Business Services yfinance.Tickers object <ACBA,ACCD,ACVA,ADV,AFRM,AHG,AKAM,ALIT,BABA,BAOS,BFH,BR,BV,CASS,CBZ,CNDT,CSGP,DHX,DLO,EGIO,ENV,EPOW,ETSY,EXLS,FA,FI,FICO,FIS,FLT,FTFT,FVRR,GPN,GRAB,GRABW,GRVY,HGBL,HQY,HRT,HSTM,IFIN,IIIV,IMXI,KODK,KRKR,LQDT,LYFT,MA,MCHX,MELI,MMS,MOGU,MPLN,MSCI,NCTY,OPRX,PALT,PAYS,PDD,PHR,PRTH,PSFE,PYPL,QH,QNST,RBA,RDWR,RELX,RGP,RMNI,RPAY,RSSS,RTO,SCOR,SGRP,SHLT,TC,TCJH,TCOM,TNET,UBER,UK,UKOMW,UXIN,V,VVI,WEX,WNS,WU,XBP,XBPEW,XELA,Z,ZG,ZH>
# =========================================================================
# Publishing yfinance.Tickers object <ACCO,CMPR,ISDR,MGIH,QUAD>
# =========================================================================
# Oilfield Services/Equipment yfinance.Tickers object <ACDC,CCLP,ENSV,HAL,HLX,KLXE,LBRT,NCSM,NGS,NINE,NOA,OII,PUMP,RCON,RES,RNGR,SLB,TUSK,VIVK,WTTR,XPRO>
# =========================================================================
# Services-Misc. Amusement & Recreation yfinance.Tickers object <ACEL,AGAE,BOWL,BREA,CDRO,CDROW,CHDN,CPHC,CPOP,DIS,DKNG,EDR,EVRI,FUN,GAMB,GAME,GDEN,GDHG,GENI,IGT,LYV,MANU,MGAM,MSGE,MSGS,MTN,NGMS,RSI,SGHC,SIX,SLE,WMG,WORX,XPOF>
# =========================================================================
# Property-Casualty Insurers yfinance.Tickers object <ACGL,ACGLN,ACGLO,ACIC,AFG,AFGB,AFGC,AFGD,AFGE,AGO,ALL,AMBC,AMSF,AXS,BNRE,CB,CINF,CNA,CNFR,DGICA,DGICB,EG,EIG,ESGR,ESGRO,ESGRP,ESNT,FGF,FGFPP,GBLI,GLRE,HCI,HIG,HIPO,HMN,HRTG,ICCH,IGIC,JRVR,KFS,KINS,KMPB,KMPR,KNSL,L,LMND,MBI,MCY,MHLA,MHLD,MHNC,MKL,MTG,NMIH,NODK,ORI,OXBR,OXBRW,PGR,PLMR,PRA,RDN,RLI,RNR,ROOT,SAFT,SIGI,SIGIP,SKWD,SPNT,THG,TIPT,TRV,UFCS,UVE,WRB,WTM>
# =========================================================================
# Medical Specialities yfinance.Tickers object <ACHC,AIH,AKYA,ALHC,AMS,BACK,BGLC,BJDX,BNR,CDNA,CELC,CI,CLOV,CNC,CNTG,CSTL,DGX,DMTK,ELUT,ELV,ENZ,EXAS,FLGT,FRES,FTRE,GH,GTH,HSCS,HSCSW,HSIC,HUM,HYPR,ILMN,INBS,KEQU,LH,MHUA,MOH,NEUE,NPCE,NTRA,NXL,NXLIW,OMI,OPGN,OSA,PDCO,PMD,PRCT,PSNL,QDEL,RBOT,RDNT,RNLX,RPID,SGHT,SHC,TBIO,THMO,TLSI,TLSIW,TNON,TNONW,TRUP,UNH,VCYT,VVOS,XGN>
# =========================================================================
# Biotechnology: Biological Products (No Diagnostic Substances) yfinance.Tickers object <ACHL,ACOR,ADAP,ADMA,ADOC,ADOCR,ADOCW,ADPT,ADVM,AGEN,AIM,ALBT,ALEC,ALLO,ALVO,ALVOW,ALVR,APGE,ARGX,ARMP,ARYD,ATRA,AUTL,AVRO,AVXL,BCDA,BCLI,BCRX,BDTX,BEAM,BIIB,BLUE,BNOX,BNTX,CDTX,CGEN,CHRS,CLDI,COEP,COEPW,CRDF,CRIS,CRSP,CSBR,CVM,CYTH,CYTHW,DBVT,DNA,DNLI,DTIL,DYAI,EIGR,ENTX,ESLA,ESLAW,EVAX,EXAI,EXEL,FATE,FUSN,GENE,GILD,GMDA,GNFT,GNTA,GRTS,HALO,IBRX,IMCR,IMTX,IMTXW,IMVT,INMB,IOVA,IPHA,ITOS,KOD,KRYS,KURA,LCTX,LIFE,MESO,MGTX,MRNA,NBIX,NKGN,NKGNW,NVAX,NVO,OKYO,ONVO,OPT,PHGE,PLUR,PLX,PMCB,PROK,PSTX,QGEN,QNCX,RGEN,RGNX,RLAY,RVMD,SCNI,SGMO,SLDB,SOPH,SRRK,STRO,SWTX,TARA,TCBP,TCBPW,TCON,TECH,TTNP,TVGN,TVGNW,TWST,VALN,VCEL,VNRX,VXRT,WINT,XFOR,XTNT,ZURA,ZURAW>
# =========================================================================
# Aerospace yfinance.Tickers object <ACHR,AIR,ASLE,ASR,ASTC,AVAV,BA,BLDE,BLDEW,CAAP,ERJ,EVEX,EVTL,HEI,HON,JOBY,LILM,LILMW,OMAB,PL,RKLB,RTX,SIF,TATT,TGI,TXT,UAVS,UP,WOR>
# =========================================================================
# Food Chains yfinance.Tickers object <ACI,ASAI,CBD,DNUT,GIS,GO,IMKTA,KR,NGVC,SFM,VLGEA,WMK>
# =========================================================================
# EDP Services yfinance.Tickers object <ACIW,ACN,ADP,AEYE,AGMH,AGYS,ALKT,AMPL,APP,ARBB,ARBE,ARBEW,ARBKL,ASGN,ASUR,ATHM,AUR,AUROW,AVDX,AZPN,BASE,BBAI,BCOV,BILI,BILL,BLBX,BLND,BTCM,BTDR,CACI,CARG,CERS,CFLT,CHR,CINT,CLVT,COMP,CREX,CSGS,CSPI,CTLP,CTM,CTSH,CXAI,CXAIW,CYN,DAVA,DDI,DMRC,DOX,DSP,DTST,DTSTW,DXC,ECX,ECXWW,EGHT,EPAM,ETWO,EVCM,EVTC,EZFL,FFIV,FIVN,FORTY,FOUR,FRSH,GB,GDDY,GDEV,GDEVW,GLOB,GRDI,GRDIW,GSMGW,GTLB,HCP,HTCR,IBEX,INFA,INFY,INLX,INOD,INPX,IREN,ISSC,KD,KLTR,LAZR,LDOS,LKCO,LNW,LSAK,LYT,LZ,MARA,MLGO,MNDO,MODN,MRIN,MVLA,MVLAW,MYPS,MYPSW,NEE,NOTE,NRDS,NTCT,NTNX,OKTA,OLB,OMQS,OOMA,OSPN,PAGS,PAYO,PAYOW,PDFS,PEGA,PERI,PET,PETWW,PGRU,PHUN,PLTK,PRFT,PRO,PRST,PRSTW,PSN,RAMP,RBBN,RBLX,RCRT,RCRTW,RMBL,RNG,RSKD,RXT,S,SAI,SAIC,SAITW,SAP,SEMR,SJ,SKLZ,SLNH,SLNHP,SLP,SMAR,SMRT,SNCR,SNCRL,SOHU,SOPA,SOUN,SOUNW,SPSC,SSNC,SSNT,SSTK,STIX,STIXW,STNE,STRM,SY,TBRG,TCX,TDC,TDCX,TENB,TLS,TOST,TRAK,TRVG,TSRI,TWKS,UIS,UPWK,VERI,VNET,VRME,VRMEW,VRNT,VRSK,VRSN,VRTX,VSSYW,WAVSW,WDAY,WEAV,WIT,WIX,WKEY,WKME,WULF,WYY,XTKG,YEXT,YY,ZETA,ZFOX,ZFOXW,ZS>
# =========================================================================
# Military/Government/Technical yfinance.Tickers object <ACM,AGFY,AIRI,ATRO,BWMN,CVU,DCO,DRS,EH,ENG,ESLT,FLR,GLDD,GVA,J,KAMN,KBR,KTOS,LLAP,LMT,MG,MNTS,MNTSW,ORN,RDW,SKYH,SLND,SPR,STN,STRL,TDG,TTEK,VSEC,WLDN>
# =========================================================================
# Steel/Iron Ore yfinance.Tickers object <ACNT,ASTL,ASTLW,ATI,BYU,CMC,CRS,FRD,GDC,GGB,HUDI,IIIN,MT,MTUS,NUE,NWPX,PETZ,PKX,ROCK,SID,SIM,STLD,SXC,TS,TWI,TX,USAP,X>
# =========================================================================
# Retail: Computer Software & Peripheral Equipment yfinance.Tickers object <ACON,ACONW,AMWL,ASAN,BEAT,BEATW,BFRG,BFRGW,BSY,CCSI,CERT,CLMB,DAVE,DAVEW,DOCN,DOCS,DPSI,FOXO,GDRX,HCTI,HPE,IOT,JKHY,MKFG,ML,MYSZ,NUTX,PLTR,PLUS,PRVA,QBTS,RGTI,RGTIW,RIOT,SCSC,SNX,TASK,TGL,TTEC,U,VRAR,WGS,WGSWW,XELAP>
# =========================================================================
#  Medicinal Chemicals and Botanical Products  yfinance.Tickers object <ACRV,AKAN,ALZN,ATHA,AVIR,BCAB,BON,BTI,BTMD,CDXC,CRBU,CRON,CVKD,DYN,FHTX,FTLF,GRPH,HPCO,IMMX,IMNM,INKT,IPSC,ISPR,KAVL,KRON,KYMR,LABP,LGVN,MDWD,MO,MTEX,NAII,NVCT,OBIO,PAVS,PM,PMVP,PRLD,PRME,PXMD,RANI,RGC,RLX,SANA,SEER,SISI,SMFL,SNPX,SPRB,SRZN,SRZNW,SSIC,TARS,TKNO,TLRY,TNYA,UPXI,USNA,VERV,VGR,VRPX,VTRS,VTYX>
# =========================================================================
# Specialty Insurers yfinance.Tickers object <ACT,AIZ,AIZN,AJG,AON,ARGD,BRO,BRP,CRVL,EHTH,EQH,ERIE,FAF,FANH,FNF,GOCO,GSHD,HGTY,HUIZ,ITIC,MMC,PFG,RELI,RELIW,RYAN,SLQT,STC,TIRX,WDH,WTW>
# =========================================================================
# Multi-Sector Companies yfinance.Tickers object <ACTG,APPS,CSTE,DLB,JYNT,NTIP,REFR,RMCO,RMCOW,VHC,WPRT,XELB>
# =========================================================================
# Finance/Investors Services yfinance.Tickers object <ACV,AEF,AIO,BCAT,BCSF,BCV,BCX,BHV,BLE,BPYPP,BWG,CCIF,CET,CIK,CION,CLM,CRF,DCF,DHY,DMF,EAD,ECF,EIC,EICA,EIM,EMD,EMF,ENX,EOI,EQS,ERC,ERH,EVM,EVV,FAM,FDUS,FEI,FEN,FGB,FIF,FINS,FMY,FTF,GCMG,GCMGW,GCV,GGN,GLO,GLQ,GLU,GLV,GNT,GOF,GRF,GRX,HFRO,HIO,HIX,HNW,HTFC,IAF,ICMB,IDE,IFN,IHTA,JRS,KYN,MAIN,MATH,MFIC,MFICL,MHF,NAZ,NBH,NDP,NEA,NKX,NMCO,NMFC,NML,NMT,NMZ,NRO,NXJ,OFS,OPP,PDX,PEO,PFN,PHK,PMF,PSEC,RFM,RMI,SBI,SCM,SDHY,SLRC,SPE,STEP,TCPC,TDF,TREE,TRIN,TRINL,TURN,VFL>
# =========================================================================
# Computer Software: Prepackaged Software yfinance.Tickers object <ADBE,ADEA,ADSK,AI,AIXI,AKLI,ALAR,ALRM,ALTR,AMST,AMSWA,ANSS,AOGO,AOGOW,API,APPF,APPN,ARQQ,ARQQW,ASST,AUGX,AUID,AUUD,AUUDW,AVPT,AVPTW,AWRE,AYX,BAND,BIGC,BKKT,BKYI,BL,BLIN,BLKB,BLZE,BMBL,BMR,BOX,BRZE,CANG,CCCS,CCLD,CCLDO,CCLDP,CCRD,CDNS,CGNT,CHKP,CISO,CLBT,CLBTW,CLPS,CMAX,CMAXW,CMCM,CNXC,COUR,CRM,CRNC,CRWD,CVLT,CWAN,CXM,CYBR,DATS,DAY,DBX,DDD,DDOG,DH,DOCU,DOMO,DSGX,DT,DTSS,DUOL,DUOT,DV,EA,EGAN,ENFN,ESTC,EVBG,EXFY,FLYW,FNGR,FORA,FRGE,FROG,FRSX,FSLY,GBTG,GDYN,GEG,GEHC,GEN,GLBE,GMGI,GRND,GRRR,GRRRW,GVP,GWRE,GXAI,HKIT,HLTH,HOOD,HUBS,ICCT,ICLK,IDAI,IDN,IFBD,INSE,INST,INTA,INTU,IVDA,IVDAW,JAMF,KARO,KC,KWE,KWESW,LAW,LDTC,LDTCW,LFLY,LFLYW,LIFW,LIFWW,LPSN,LTRY,LTRYW,MANH,MBLY,MDB,MGIC,MGRX,MIXT,MKTW,MLNK,MNDY,MOMO,MQ,MSFT,MSGM,MSTR,MTC,MTLS,MTTR,NABL,NCNO,NET,NOW,NRDY,NTES,NTWK,ONTF,OPRA,ORCL,PATH,PAY,PAYC,PCOR,PCTY,PD,PERF,PRCH,PRGS,PTC,PUBM,PWSC,PYCR,QLYS,QTWO,RBT,RDVT,RELY,RPD,RTC,RUM,RUMBW,SBET,SCWX,SHCR,SHCRW,SHOP,SKIL,SMSI,SNAL,SNCE,SNOW,SNPS,SPLK,SPNS,SPT,SQ,SQSP,SSTI,STEM,STER,SWI,SWVL,SWVLW,TAOP,TEAM,TTWO,TUYA,TWLO,TWOU,TYL,UPLD,VCSA,VEEV,VERX,VMEO,VRNS,VTEX,WAVD,WETG,WFCF,WIMI,WK,XNET,YMM,YOU,ZDGE,ZENV,ZI,ZUO>
# =========================================================================
# Engineering & Construction yfinance.Tickers object <ADD,AGX,AMRC,APG,BBCP,BBU,BLD,EME,FIX,IESC,LMB,MTRX,PWR,ROAD,WLGS>
# =========================================================================
# Packaged Foods yfinance.Tickers object <ADM,AFRI,AFRIW,BG,BGS,BHIL,BOF,BRBR,BRFH,BYND,CAG,CHSN,CPB,DAR,FAMI,FARM,FLO,FRPT,GWAV,INGR,JVA,K,KHC,KLG,LANC,LSF,LW,LWAY,MDLZ,MED,MKC,NOMD,OTLY,PLAG,POST,RGF,SENEA,SENEB,SJM,SMPL,SNAX,SNAXW,SOVO,STKH,THS,UTZ,VITL>
# =========================================================================
# Auto Parts:O.E.M. yfinance.Tickers object <ADNT,AEVA,ALSN,ALV,APOG,APTV,ATMU,AXL,BWA,CAAS,CPS,CVGI,DAN,DORM,EVTV,GNTX,GOEVW,GTX,HLLY,IEP,INVZ,INVZW,LCII,LEA,LIDR,LIDRW,MGA,MOD,MPAA,PATK,QS,SES,SMP,SPRU,SRI,STRT,SUP,THRM,TT,VC,WKSP,WKSPW>
# =========================================================================
# Industrial Specialties yfinance.Tickers object <ADSE,ADSEW,AIT,ALGN,APT,AVNS,AZZ,BBLG,BBLGW,BLNK,BOOM,CDRE,CLGN,DOOO,DSGR,ENOV,ESTA,EW,FGI,HDSN,INGN,LAKE,LFWD,LGMK,LUNG,MEC,MLSS,MODD,MSA,MTRN,MYO,NAOV,NTIC,NTRBW,OFLX,PII,PKOH,POAI,POOL,RDUS,SNN,SPLP,STE,TRS,UGRO,VIRC,WBX,WLFC,XPEL,ZBH,ZJYL>
# =========================================================================
# Advertising yfinance.Tickers object <ADTH,ADTHW,ANGI,ANTE,CCO,CRTO,CTV,DLX,EEX,FLNT,GRPN,HHS,INUV,IPG,IZEA,LDWY,MFC,MGOL,NCMI,OMC,PSQH,STBX,STCN,SURG,SURGW,SWAG,TSQ,TZOO,WPP,ZTO>
# =========================================================================
# Telecommunications Equipment yfinance.Tickers object <ADTN,AKTS,ALLT,ALPP,AMPG,AMX,ANGH,ANGHW,APWC,ASNS,ASTS,ASTSW,ATEX,ATNI,ATUS,AUDC,BCE,BDC,CALX,CCOI,CHT,CIEN,CLFD,CNSL,CTBB,CTDD,CXDO,DZSI,ESE,FKWL,FN,FYBR,GOGO,GSAT,HEAR,IDCC,IDT,IHS,INFN,INSG,IRDM,ITI,KORE,KSCP,KT,LUMN,MIMO,MINM,MITQ,NSSC,NTGR,NXPL,NXPLW,OCC,ORAN,PEGY,PHI,PWFL,REKR,SATS,SHEN,SIDU,SKM,SNT,SONM,SPIR,SPOK,T,TBB,TBC,TDS,TEF,TEO,TIGO,TIMB,TKC,TLK,TMUS,TTGT,TU,UCL,USM,UTSI,UZD,UZE,UZF,VEON,VISL,VIV,VOD,VZ,WCC,ZD>
# =========================================================================
# Medical/Nursing Services yfinance.Tickers object <ADUS,AHCO,AIRS,AMED,AONC,AONCW,ATPC,CCM,CHE,DHAC,DHACW,FHLT,FHLTW,HIMS,INNV,LFMD,LFMDP,LFST,OPCH,PIII,PIIIW,PNTG,TALK,TALKW,TDOC,TOI,TOIIW,USPH>
# =========================================================================
# Oil Refining/Marketing yfinance.Tickers object <AE,ARKO,ARKOW,BANL,BCO,CAPL,CHRW,EXPD,FWRD,GEL,GLP,HUBG,JYD,MMLP,NVVE,NVVEW,RLGT,SGLY,WKC>
# =========================================================================
# Power Generation yfinance.Tickers object <AEE,ALCE,ALE,AVA,CETY,CMS,CMSA,CMSC,CMSD,CREG,DUK,DUKB,ED,ENJ,ENO,EVRG,EXC,GNE,LNT,NI,NOVA,NWE,PCG,SO,SOJC,SOJD,UTL,VIA,VIASP,VVPR,WEC,XEL>
# =========================================================================
# Building Products yfinance.Tickers object <AEHL,AUVI,AUVIP,AYI,BW,BWNB,BWSN,EFOI,GFF,GIL,JBI,LYTS,MAS,OESX,PGTI,SKYX>
# =========================================================================
# Electrical Products yfinance.Tickers object <AEHR,ALNT,APH,BHE,CETX,COHU,ELTK,FEIM,FLEX,HUBB,INTT,ITRI,JBL,KTCC,KULR,LFUS,MEI,MRCY,NNDM,OLED,PLXS,POWL,PPSI,RFIL,SANM,SGMA,SLDP,SLDPW,SMR,TER,TRNS,TTMI,VLTO,VPG,VSH>
# =========================================================================
# Building operators yfinance.Tickers object <AEI,BAM,BN,BNH,BNJ,DOUG,GYRO,INTG,MAYS,NEN,PDM,TPHS>
# =========================================================================
# Medical/Dental Instruments yfinance.Tickers object <AEMD,ANGO,ANIK,AORT,APYX,ARAY,AREN,ASXC,ATEC,ATR,ATRC,ATRI,AVGR,AWH,AXNX,BAX,BDX,BIOL,BLFS,BSX,BTCY,BWAY,CATX,CLPT,CODX,CTCX,CTCXW,CTSO,DCTH,DRIO,DRTSW,DXCM,DXR,DYNT,EMBC,FEMY,GCTK,GKOS,GMED,HAE,IART,ICAD,ICUI,IINN,IINNW,INFU,INO,INSP,INVO,IONM,IRMD,IRTC,ISRG,KIDS,KRMD,LMAT,LYRA,MASS,MBOT,MDAI,MDAIW,MDGS,MGRM,MMM,MMSI,MOTS,NARI,NEPH,NMTC,NSPR,NURO,NVAC,NVACR,NVACW,NVCR,NVNO,NVRO,NVST,NXGL,NXGLW,NYXH,OFIX,OMIC,OSUR,PAVM,PAVMZ,PDEX,PEN,PETV,PETVW,PLSE,PODD,PROF,PSTV,PYPD,QNRX,RCEL,RMD,RSLS,RVP,SIBN,SILK,SINT,SMTI,SRDX,SRTS,SSKN,STIM,STSS,SWAV,SYK,TCMD,TELA,TFX,TNDM,TTOO,UFPT,UTMD,VERO,VTAK,WST,XAIR,XRAY>
# =========================================================================
# Durable Goods yfinance.Tickers object <AENT,AENTW,CNM,CPNG,GNLN,WISH>
# =========================================================================
# Clothing/Shoe/Accessory Stores yfinance.Tickers object <AEO,ANF,BKE,BOOT,CATO,CTRN,CURV,DBGI,DBGIW,DBI,DLTH,DXLG,FL,GCO,GPS,HBI,JILL,JWN,LE,PLCE,ROST,SCVL,TJX,TLYS,URBN,VNCE,VSCO,ZUMZ>
# =========================================================================
# Electric Utilities: Central yfinance.Tickers object <AEP,AES,AGR,AMPS,AQN,AQNB,AQNU,AY,BEP,BKH,CEG,CEPU,CIG,CNP,CWEN,DTB,DTE,DTG,DTW,EAI,EBR,EDN,EIX,ELC,ELLO,ELP,ELPC,ENIC,ES,ETR,FE,FTS,GPJA,HE,IDA,KEN,KEP,MGEE,NEP,NRG,OGE,ORA,OTTR,PAM,PEG,PNM,PNW,POR,PPL,RNW,RNWWW,TAC,TVC,TVE,VST,WAVE>
# =========================================================================
# Professional Services yfinance.Tickers object <AERT,AINC,ARC,ASTH,ATIF,ATXG,BAH,BBSI,BGSF,CCRN,DLHC,EFSH,EXPO,FC,FCN,FRGT,G,GRNQ,HCKT,HQI,HSON,HURN,ICFI,III,KELYA,KELYB,KFRC,LTBR,MAN,MEG,MHH,NSP,RCMT,RHI,RVYL,SRL,STAF,TBI,WHLM>
# =========================================================================
# Trusts Except Educational Religious and Charitable yfinance.Tickers object <AFB,AGD,AVK,AWF,AWP,BANX,BGB,BGR,BGT,BGX,BGY,BIT,BKN,BME,BMEZ,BMN,BNY,BOE,BRW,BSL,BSTZ,BTA,BUI,BXSL,CBH,CCD,CEM,CIF,CPZ,DMA,DMB,DMO,DPG,DSL,ECAT,ECC,ECCC,ECCV,ECCW,ECCX,EEA,EFR,EGF,EOS,FFC,FLC,FPF,FPL,FSCO,FT,GGT,GHY,GUG,GUT,HGLB,HIE,HPI,HTY,IAE,IGD,IIF,ISD,JCE,JFR,JHI,JMM,JOF,KSM,LEO,MCI,MCR,MFD,MFV,MGF,MIN,MMT,MSD,MXF,NBXG,NDMO,NHS,NIM,NMI,NPFD,NQP,NRK,NUV,NXN,NXP,OCCI,OCCIN,OCCIO,PAI,PCF,PCK,PCM,PDI,PDO,PMX,PNI,PTA,RFMZ,RGT,RMM,RQI,RVT,SCD,SPXX,TEAF,TTP,TWN,VBF,VCV,VGM,VKQ,VLT,VMO,VPV,VVR,WDI,WEA,WIA>
# =========================================================================
# Biotechnology: Electromedical & Electrotherapeutic Apparatus yfinance.Tickers object <AFIB,AXGN,BSGM,BVS,CNMD,CTKB,CUTR,CVRX,ECOR,EDAP,ELMD,FNA,FONR,HSDT,INMD,IRIX,ITGR,LIVN,LUCD,MASI,MDT,MOVE,MXCT,NDRA,NUWE,OM,OWLT,POCI,PRKS,QTI,RXST,SMLR,STRR,STRRP,STXS,TIVC,TLIS,TMCI,TMDX,VANI,ZIMV,ZYXI>
# =========================================================================
# Accident &Health Insurance yfinance.Tickers object <AFL,EBC,OSCR,UNM,UNMA>
# =========================================================================
# Precious Metals yfinance.Tickers object <AG,ASA,ATCOL,AU,AUMN,AUST,BTG,BVN,CDE,CGAU,CHNR,CMCL,CTGO,DC,DRD,EQX,EXK,FURY,GATO,GFI,GLDG,GORO,GROY,HL,HMY,HYMC,HYMCL,HYMCW,IAUX,IDR,KGC,MAG,MTA,MUX,NAK,NEM,NEWP,NFGC,NG,OR,ORLA,PPTA,RGLD,SA,SAND,SBSW,SSRM,STKL,SVM,TMQ,TRX,URG,USGO,USGOW,VGZ,WPM,XPL>
# =========================================================================
# Managed Health Care yfinance.Tickers object <AGL,AGTI,BRTX,CCEL,DCGO,MRAI>
# =========================================================================
# Finance Companies yfinance.Tickers object <AGM,AIF,BBN,BDJ,BFK,BFZ,BHK,BST,BTZ,CEE,CSQ,CSWCZ,DHF,DIAX,DSU,ECPG,EDD,EFT,ETJ,ETY,EVT,EXG,FCT,FOA,GDO,GECCO,GECCZ,HPF,HQH,HTD,HYT,IGR,IQI,JHS,JPI,JQC,JRI,KTF,LDP,MAV,MCVT,MFM,MPA,MPV,MXE,MYN,NBB,NCV,NCZ,NIO,NMS,NTG,NZF,OFSSH,OIA,OXLCL,OXLCZ,PDT,PFL,PFO,PGP,PIM,PLBC,PMO,PMTS,PNF,PPT,QQQX,RIV,SRV,SWZ,TEI,THQ,THW,TY,USA,UTF,VKI,VTN,WHF,WIW>
# =========================================================================
# Farming/Seeds/Milling yfinance.Tickers object <AGRO,ANDE,AVO,CALM,CHSCL,CHSCM,CHSCN,CHSCO,CHSCP,CTVA,DOLE,DTCK,EDBL,EDBLW,FDP,LMNR,LND,LOCL,NCRA,SANW,SEB,SEED,SVFD,UVV,YOTA,YOTAU,YOTAW>
# =========================================================================
# Miscellaneous manufacturing industries yfinance.Tickers object <AGS,AMCR,BRC,DAKT,DOGZ,HI,JCSE,MWG,ODC,SASI,SHPW,SHPWW,VTSI>
# =========================================================================
# Textiles yfinance.Tickers object <AIN,CRWS,CSWC,CULP,GLAD,UFI>
# =========================================================================
# Radio And Television Broadcasting And Communications Equipment yfinance.Tickers object <AIRG,AVNW,BKSY,BKTI,CAMP,CASA,CLRO,CMBM,CMTL,COMM,CRNT,DGLY,ERIC,GILT,HLIT,KVHI,MSI,NOK,ONDS,SATL,SATLW,SATX,TROO,UI,VSAT,WATT>
# =========================================================================
# Catalog/Specialty Distribution yfinance.Tickers object <AKA,AMZN,BWMX,BYON,BZUN,CDW,CHWY,CNXN,DDL,DIBS,EBAY,GCT,HEPS,HNST,HOUR,IPW,JMIA,LITB,LVLU,MYTE,NSIT,PIK,QRTEA,QRTEB,QRTEP,QVCC,QVCD,RVLV,SFIX,TDUP,VIPS,W,WNW>
# =========================================================================
# Major Chemicals yfinance.Tickers object <ALB,ALTO,AMTX,APD,ARQ,ASIX,ASPI,AVNT,BAK,BCPC,CBT,CC,CDXS,CE,CNEY,DD,DNMR,DOW,ECVT,EMN,ESI,FEAM,FF,FMC,FSI,FTK,GEVO,GPRE,GURE,HUN,HXL,IFF,IOSP,IPI,KRO,KWR,LIN,LNZA,LNZAW,LODE,LOOP,LXFR,LXU,LYB,MTX,NEU,NGVT,NL,OEC,OLN,ORGN,ORGNW,REX,SEE,SLI,SXT,TROX,TSE,VGAS,VGASW,VHI,VVV,WDFC,WLK,WLKP,ZTEK>
# =========================================================================
# Ophthalmic Goods yfinance.Tickers object <ALC,COO,EYE,LUCY,LUCYW,STAA,WRBY>
# =========================================================================
# Other Specialty Stores yfinance.Tickers object <ALLG,AN,ARHS,BGFV,BNED,BQ,CPRT,CRMT,DKS,EVGO,EVGOW,EZPW,FLWS,HITI,HVT,JD,JFBR,JFBRW,JOAN,KIRK,LAD,LIVE,LOVE,MI,NAAS,NE,NEGG,NUZE,ODP,REAL,RENT,RERE,RH,RUSHA,SBH,SGU,SPH,SPWH,SVV,SYRA,TITN,TKLF,ULTA,VRM,WINA,WOOF,YJ>
# =========================================================================
# Computer peripheral equipment yfinance.Tickers object <ALOT,DGII,DM,EVLV,EVLVW,FATH,FTNT,IMMR,INVE,JNPR,LITE,LOGI,MITK,PANW,QCOM,RDCM,SSYS,TACT,XRX,ZBRA>
# =========================================================================
# Natural Gas Distribution yfinance.Tickers object <AM,CLNE,DINO,DKL,ENB,ENLC,EPD,ET,ETRN,HTOO,HTOOW,KMI,MNTK,MPLX,NGG,NGL,NS,NSS,OPAL,PAA,SMLP,SREA,TGS,TRGP,UGI,UGIC,USAC,WES,WMB>
# =========================================================================
# Commercial Banks yfinance.Tickers object <AMAL,AVAL,BAP,BBAR,BBVA,BCH,BCS,BLFY,BLX,BMA,BRBS,BSAC,BSBR,CIB,ESQ,FINW,GGAL,HDB,HNVR,IBN,IFS,ING,KB,LYG,MBNKP,MUFG,NTB,NWG,PGC,SAN,SMFG,SSBK,SUPV,TD,TECTP,VBNK,WF>
# =========================================================================
# Environmental Services yfinance.Tickers object <AMBI,AWX,CLH,CWST,GFL,LICY,PCT,PCTTU,PCTTW,PESI,QRHC,RSG,SCWO,SRCL,WCN,WM>
# =========================================================================
# Containers/Packaging yfinance.Tickers object <AMBP,AVY,BALL,CCK,DSS,GPK,ITP,KMB,OI,PACK,PKG,PTVE,SLGN,SON,STVN,WMS>
# =========================================================================
# Movies/Entertainment yfinance.Tickers object <AMC,BATRA,BZFD,BZFDW,CNK,CSSE,CSSEL,CSSEN,CSSEP,CURI,CURIW,FWONA,FWONK,GAIA,HOFV,HOFVW,IMAQ,IMAQR,LSXMB,LSXMK,MCS,RDI,RDIB,RSVR,RSVRW,SPHR,TOON>
# =========================================================================
# Cable & Other Pay Television Services yfinance.Tickers object <AMCX,CABO,CCZ,CHTR,CMCSA,LBRDA,LBRDK,LBRDP,LBTYA,LBTYB,LBTYK,LILA,LILAK,RCI,ROKU,WBD,WOW>
# =========================================================================
# Assisted Living Services yfinance.Tickers object <AMN,HCSG>
# =========================================================================
# Oil & Gas Production yfinance.Tickers object <AMPY,APA,AR,AROC,BATL,BORR,BRN,BRY,BSM,CEI,CHK,CHKEL,CHKEW,CHKEZ,CHRD,CIVI,CKX,CLMT,CNQ,CNX,CPE,CPG,CPK,CRC,CRGY,CRK,CRT,CTRA,CVE,DMLP,DO,DTM,DVN,DWSN,E,EC,EGY,EOG,EP,EPM,EPSN,EQT,FANG,GBR,GPOR,GPRK,GTE,HESM,HNRA,HP,HPK,HPKEW,HUSA,ICD,INDO,KGEI,KNTK,KOS,KRP,MARPS,MGY,MRO,MTDR,MTR,MUR,MVO,MXC,NBR,NEXT,NOG,NRT,OBE,OKE,OSG,OVV,OXY,PAGP,PARR,PBA,PBR,PBT,PED,PFIE,PHX,PNRG,PR,PRT,PRTG,PTEN,PVL,PXD,REI,REPX,RGCO,RIG,RRC,SBOW,SBR,SD,SDRL,SHEL,SJT,SM,SSL,STR,SWN,SWX,TALO,TELZ,THWWW,TPET,TPL,TTE,TTI,TXO,USEG,VAL,VET,VIST,VNOM,VOC,VTLE,VTS,WDS,WTI>
# =========================================================================
# Coal Mining yfinance.Tickers object <AMR,ARCH,AREC,ARLP,BTU,CEIX,HCC,HNRG,METC,METCB,METCL,NC,NRP>
# =========================================================================
# Forest Products yfinance.Tickers object <AMWD,DOOR,EVA,FBIN,JELD,KOP,LPX,TREX,UFPI,WFG>
# =========================================================================
# Computer Communications Equipment yfinance.Tickers object <ANET,ATEN,BOSC,CSCO,EXTR,INTZ,LTRX,WLDS,WLDSW>
# =========================================================================
# Consumer Electronics/Appliances yfinance.Tickers object <AOS,ARLO,EMR,FIP,GE,GLLI,GLLIU,GLLIW,GLST,GLSTU,GLSTW,GNSS,IMTE,IRBT,KN,KOSS,MSN,OTIS,SONO,SONY,THCP,TRNR,UEIC,VIOT,VZIO,WHR,WTO>
# =========================================================================
# Ordnance And Accessories yfinance.Tickers object <AOUT,AXON,NPK,POWW,POWWP,RGR,SWBI,VSTO,WRAP>
# =========================================================================
# Fluid Controls yfinance.Tickers object <AP,FLS,GGG,GRC,IEX,ITT,XYL>
# =========================================================================
# Meat/Poultry/Fish yfinance.Tickers object <AQB,BRFS,BTE,HRL,PPC,TSN>
# =========================================================================
# Trucking Freight/Courier Services yfinance.Tickers object <ARCB,CVLG,HTLD,JBHT,KNX,LSTR,MRTN,ODFL,PTSI,SAIA,SFWL,SNDR,TFII,ULH,UPS,WERN>
# =========================================================================
# Restaurants yfinance.Tickers object <ARCO,ARKR,ARMK,BDL,BFI,BFIIW,BH,BJRI,BLMN,BROS,BTBD,BTBDW,CAKE,CAVA,CBRL,CHUY,CMG,CNNE,DENN,DIN,DRI,EAT,FAT,FATBB,FATBP,FATBW,FWRG,GENK,GTIM,JACK,KRUS,LOCO,LVO,MCD,NATH,NDLS,PBPB,PLAY,PTLO,PZZA,QSR,REBN,RICK,RRGB,SBUX,SDOT,SG,SHAK,STKS,TAST,TXRH,WEN,WING,YOSH,YUM,YUMC>
# =========================================================================
# Plastic Products yfinance.Tickers object <AREB,AREBW,AWI,AZEK,BERY,CMT,DSWL,KRT,LWLG,MYE,NWL,SWIM,TUP>
# =========================================================================
# Water Supply yfinance.Tickers object <ARIS,ARTNA,AWK,AWR,CDZI,CDZIP,CWCO,CWT,GWRS,MSEX,PCYO,SBS,SJW,WTRG,YORW>
# =========================================================================
# Electronic Components yfinance.Tickers object <ARW,AVT,CAMT,COHR,DCFC,DCFCW,DFLI,DFLIW,DPRO,HAYW,ITRN,KLAC,NTAP,NVMI,OPXS,PSTG,QMCO,RELL,STX,TAIT,TGLS,UUU,VIEW,VIEWW,VOXX,WDC,XPON>
# =========================================================================
# Marine Transportation yfinance.Tickers object <ASC,BIP,BIPC,CACO,CCL,CISS,CMRE,CPLP,CTRM,CUK,DAC,DHT,DLNG,DSX,EDRY,EGLE,ESEA,EURN,FLNG,FRO,FRZA,GASS,GD,GLBS,GLNG,GNK,GOGL,GRIN,GSL,IMPP,IMPPP,INSW,KEX,KNOP,LPG,MATX,MBUU,MCFT,MPX,NAT,NCLH,NMM,NVGS,OMEX,PANL,PSHG,PXS,PXSAP,PXSAW,RCL,SB,SBBA,SBLK,SFL,SMHI,STNG,TDW,TK,TNK,TNP,TOPS,TORO,TRMD,USEA,VEEE,VMAR,ZIM>
# =========================================================================
# Specialty Chemicals yfinance.Tickers object <ASH,CLX,CSL,HWKN,KVUE>
# =========================================================================
# Recreational Games/Products/Toys yfinance.Tickers object <ASO,BBW,BHAT,CLAR,CNXA,DTC,ESCA,FNKO,GOLF,HAS,JAKK,JOUT,MAT,MODG,PLBY,PTON,YETI>
# =========================================================================
# RETAIL: Building Materials yfinance.Tickers object <ASPN,BCC,BECN,BLDR,FAST,FND,GRWG,HD,JCTCF,LL,LOW,SGBX,SHW,TSCO>
# =========================================================================
# Construction/Ag Equipment/Trucks yfinance.Tickers object <ASTE,BLBD,CAT,CMCO,CNHI,GENC,GP,HY,HYLN,HYZN,HYZNW,MLR,MTW,PLOW,TEX,WNC,XOS,XOSWW>
# =========================================================================
# Transportation Services yfinance.Tickers object <ASTR,BKNG,DESP,DSKE,EXPE,GATX,GXO,LIND,MDV,MMYT,MODV,MOND,SPCE,SRFM,TOUR,VRRM,VTOL,XPO,YGMZ,YTRA>
# =========================================================================
# Home Furnishings yfinance.Tickers object <ATER,BSET,CODI,CSWI,DXYN,ETD,FLXS,FUL,HBB,HELE,HOFT,JAN,LEG,LZB,MHK,NTZ,NVFY,PRPL,SNBR,TCS,TILE,TPX,WSM>
# =========================================================================
# Hospital/Nursing Management yfinance.Tickers object <ATIP,AVAH,BKD,BKDT,CYH,EHAB,EHC,ENSG,HCA,MD,NHC,SEM,SGRY,SNDA,SSY,THC,UHS>
# =========================================================================
# Mining & Quarrying of Nonmetallic Minerals (No Fuels) yfinance.Tickers object <ATLX,CMP,GAU,LEU,MDU,MLM,SLCA,SND,SQM,SUM,TECK,UUUU,VMC>
# =========================================================================
# Oil/Gas Transmission yfinance.Tickers object <ATO,CQP,EE,LNG,NFE,NFG,NJR,NWN,OGS,SLNG,SR,SRE,UGP>
# =========================================================================
# Agricultural Chemicals yfinance.Tickers object <AVD,BIOX,CBUS,CF,CGA,EVGN,ICL,MBC,MOS,NTR,RKDA,SMG,SNES,UAN>
# =========================================================================
# Savings Institutions yfinance.Tickers object <AX,BAFN,BCBP,BFIN,BKU,BRKL,BVFL,BYFC,CARV,CFFN,CLBK,CULL,CVLY,CZWI,FCAP,FGBI,FGBIP,FMAO,FNWD,FSEA,FSFG,HFBL,HMNF,HSBC,HTBI,KFFB,KRNY,LSBK,MGYR,NECB,NFBK,NRIM,NSTS,PFS,PROV,ROMA,SBT,SFBC,TBNK,TFSL,WMPN,WNEB,WSBF>
# =========================================================================
# Package Goods/Cosmetics yfinance.Tickers object <AXIL,CHD,CL,COTY,ECL,EL,ELF,EPC,EWCZ,GROV,HLN,IPAR,OLPX,PG,SCL,SKIN,UG,UL,WALD,WALDW,YSG>
# =========================================================================
# Homebuilding yfinance.Tickers object <AXR,BZH,CCS,CVCO,DFH,DHI,GEO,GRBK,HOV,HOVNP,IBP,IRS,JOE,KBH,LEGH,LEN,LGIH,LSEA,LSEAW,MDC,MHO,MTH,NVR,PHM,SKY,STRS,THO,TMHC,TOL,TPH,UHG,UHGWW,WGO,XIN>
# =========================================================================
# Paints/Coatings yfinance.Tickers object <AXTA,PPG,RPM>
# =========================================================================
# Department/Specialty Retail Stores yfinance.Tickers object <BARK,BIG,BJ,BURL,COST,DDS,DDT,DG,DLTR,FIVE,KSS,M,MNSO,OLLI,PSMT,TGT,WMT>
# =========================================================================
# Broadcasting yfinance.Tickers object <BATRK,BBGI,CMLS,EVC,FENG,FOX,FOXA,FUBO,GTN,IHRT,LLYVA,LLYVK,LPTV,LSXMA,MDIA,NXST,PARA,PARAA,PARAP,SBGI,SGA,SIRI,SPOT,SSP,TGNA,TME,TV,UONE,UONEK>
# =========================================================================
# Diversified Financial Services yfinance.Tickers object <BBDC,IX,NRUC,SEZL,SOFI,SWKH>
# =========================================================================
# Consumer Electronics/Video Chains yfinance.Tickers object <BBY,CNVS,CONN,IQ,IZM,NFLX>
# =========================================================================
# Precision Instruments yfinance.Tickers object <BDSX,ISPC,ME,NEO,SERA>
# =========================================================================
# Medical Electronics yfinance.Tickers object <BFLY,CHEK,HOLX,LNSR,NNOX,PHG>
# =========================================================================
# Consumer Specialties yfinance.Tickers object <BGI,BRLT,CENT,CENTA,CTHR,EDUC,ELA,FOSL,FOSLL,JEWL,MOV,SIG>
# =========================================================================
# Banks yfinance.Tickers object <BHLB,BSBK,ECBK,ESSA,FFNW,FNWB,FSBC,FSBW,GCBC,HBCP,HFWA,NYCB,PBBK,PBFS,PVBC,SMBC,TCBS,TCBX,TSBK>
# =========================================================================
# Other Pharmaceuticals yfinance.Tickers object <BIMI,CAH,COR,COSM,HLF,HWH,MCK,MEDS,NUS,PETQ>
# =========================================================================
# Apparel yfinance.Tickers object <BIRD,COLM,CPRI,CRI,CTAS,DLA,FIGS,GES,GIII,GOOS,JRSH,JXJT,KTB,LEVI,LULU,OXM,PVH,RL,SGC,SILO,TLF,TPR,UA,UAA,VFC,VRA,WEYS,ZGN>
# =========================================================================
# Integrated oil Companies yfinance.Tickers object <BP,BPT,BROG,BROGW,COP,CVI,CVX,DK,EQNR,HES,IMO,MPC,PBF,PSX,SU,SUN,VLO,VTNR,XOM,YPF>
# =========================================================================
# Specialty Foods yfinance.Tickers object <BRID,CVGW,FREE,FREEW,HSY,JBSS,JJSF,MAMA,RMCF,TR>
# =========================================================================
# Wholesale Distributors yfinance.Tickers object <BXC,COOK,CRCT,IONQ,RCAT,REZI,STRC,STRCW,VLD>
# =========================================================================
# Shoe Manufacturing yfinance.Tickers object <CAL,CROX,DECK,NKE,ONON,RCKY,SHOO,SKX,WWW>
# =========================================================================
# Rental/Leasing Companies yfinance.Tickers object <CAR,GETR,HTZ,HTZWW,MRT,R,SP,UHAL>
# =========================================================================
# Biotechnology: Commercial Physical & Biological Resarch yfinance.Tickers object <CDIO,CDIOW,CRL,ICLR,INCY,IQV,LUNA,MEDP,NOTV,NRC,ONMDW>
# =========================================================================
# Pollution Control Equipment yfinance.Tickers object <CECO,DCI,FTEK,PPIH>
# =========================================================================
# Auto Manufacturing yfinance.Tickers object <CENN,CJET,ECDA,ECDAW,F,FFIE,FFIEW,FSR,FSS,GGR,GGROW,GM,HMC,IDEX,KNDI,LCID,LEV,LI,MULN,NIU,NKLA,NWTN,NWTNW,OSK,PCAR,PEV,PSNY,PSNYW,RACE,REE,REVG,RIVN,SHYF,SOLO,STLA,TM,TSLA,VLCN,WKHS,XPEV>
# =========================================================================
# Food Distributors yfinance.Tickers object <CHEF,DIT,DPZ,HFFG,HIBB,PFGC,RAVE,SPTN,SYY,UNFI,USFD,WILC>
# =========================================================================
# Retail-Drug Stores and Proprietary Stores yfinance.Tickers object <CJJD,CVS,PETS,WBA,YI>
# =========================================================================
# Paper yfinance.Tickers object <CLW,GLT,IP,MATV,MERC,RYAM,SLVM,SUZ>
# =========================================================================
# Professional and commerical equipment yfinance.Tickers object <CLWT,SITE>
# =========================================================================
# Railroads yfinance.Tickers object <CNI,CP,CSX,GBX,NSC,RAIL,TRN,UNP,WAB>
# =========================================================================
# Building Materials yfinance.Tickers object <CPAC,CPSH,CRH,CX,EXP,JHX,LOMA,SMID,VEV>
# =========================================================================
# Office Equipment/Supplies/Services yfinance.Tickers object <CXT,DBD,EBF,ESAB,GWW,HAIN,HNI,ILAG,MLKN,PAR,PBI,PRLB,REYN,SCS>
# =========================================================================
# Newspapers/Magazines yfinance.Tickers object <DALN,DJCO,GCI,LEE,NWS,NWSA,NYT,PRM,SOBR>
# =========================================================================
# Other Metals and Minerals yfinance.Tickers object <DNN,EU,FMST,FMSTW,GSM,LITM,NMG,NXE,PLL,UEC,USLM,WWR>
# =========================================================================
# Automotive Aftermarket yfinance.Tickers object <DRVN,GPC,GT,MNRO,NXU>
# =========================================================================
# Misc Health and Biotechnology Services yfinance.Tickers object <DVA,FMS,LSTA,OTRK,PGNY,QIPT,VMD>
# =========================================================================
# Water Sewer Pipeline Comm & Power Line Construction yfinance.Tickers object <DY,ESOA,MTZ,MYRG,PLPC,PRIM>
# =========================================================================
# Motor Vehicles yfinance.Tickers object <EZGO,FOXF,FUV,HOG,LKQ,ZAPP>
# =========================================================================
# Miscellaneous yfinance.Tickers object <FERG>
# =========================================================================
# Misc Corporate Leasing Services yfinance.Tickers object <FTAI,FTAIM,FTAIN,FTAIO,FTAIP,HEES,HRI,WSC>
# =========================================================================
# Electronics Distribution yfinance.Tickers object <GME,SNPO>
# =========================================================================
# Diversified Electronic Products yfinance.Tickers object <MICS>
# =========================================================================
# Books yfinance.Tickers object <PSO,SCHL,WLY,WLYB>
# =========================================================================
# Tobacco yfinance.Tickers object <TPB>
# =========================================================================
# General Bldg Contractors - Nonresidential Bldgs yfinance.Tickers object <TPC>
# =========================================================================
# Tools/Hardware yfinance.Tickers object <TTC>
# =========================================================================

# %%
industries = nasdaq_screner.Industry.unique()

for ind in industries:
    ind_companies = nasdaq_screener[nasdaq_screener['Industry'] == ind]['Symbol']
        all_companies = None
        for company in ind_companies:
            tickr = yf.Ticker(company)
            
            if(all_companies is None):
                df.add_suffix(f'_{company}')
                df.rename(columns={df.columns.values[0]:'date'})
                all_companies = df
            else:
                all_companies.join(other=df, on='date', how='inner', rsuffix=f'_{company}')
        print(all_companies.info())
